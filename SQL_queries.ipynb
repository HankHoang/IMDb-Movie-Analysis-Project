# %% [markdown]
# # Extracting insights from SQL queries using DuckDB
# ### *Author: Hank Hoang*
# ### *Date created: 03/07/2023*
# ### *Date finished: 04/07/2023*

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import duckdb
connection = duckdb.connect()

# %%
#Reading the data
file_path = '/content/drive/MyDrive/IMDb_data.csv'
df = pd.read_csv(file_path)
# Out:
# <ipython-input-3-ced02e518387>:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
print(df.dtypes)
# Out:
# tconst              object
# Type                object
# Title               object
# isAdult              int64
# startYear           object
# endYear             object
# Runtime             object
# Genres              object
# Rating             float64
# Number of Votes      int64
# Director Name       object
# dtype: object

# %% [markdown]
# ### Rename Number of Votes column to call in SQL query

# %%
column_name_mapping = {'Number of Votes': 'NumberofVotes','Director Name':'DirectorName'}

# Use the rename() method on the DataFrame
df.rename(columns=column_name_mapping, inplace=True)

# %% [markdown]
# ## Subset data without N/A Values in Runtime column

# %%
subset_df = df[~df['Runtime'].str.contains('N')]
# Convert the 'Runtime' column to integer
subset_df['Runtime'] = subset_df['Runtime'].astype(int)
# Out:
# <ipython-input-74-5e017314edfc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['Runtime'] = subset_df['Runtime'].astype(int)

# %% [markdown]
# ## Implement SQL queries with DuckDB

# %%
# DuckDB connection
con = duckdb.connect(database=":memory:", read_only=False)

# %%
# Making SQL query for example
con.execute("SELECT Title FROM df ")
result = con.fetchdf()

# %%
# Select Title column
result
# Out:
#                             Title
# 0                      Carmencita
# 1          Le clown et ses chiens
# 2                  Pauvre Pierrot
# 3                     Un bon bock
# 4                Blacksmith Scene
# ...                           ...
# 944650                  Pink Taxi
# 944651        Kuambil Lagi Hatiku
# 944652            My Sweet Prince
# 944653  The Trial of Joan Collins
# 944654                     6 Gunn
#
# [944655 rows x 1 columns]

# %% [markdown]
# ## *Q1: How many movies have rating above than 7?*

# %%
con.execute("SELECT COUNT(*) AS RESULT FROM df WHERE Rating > 7;")
result = con.fetchdf()
result
# Out:
#    RESULT
# 0  482608

# %% [markdown]
# ## *Q2: How many movies have rating above than 7 less than 30 minutes  ?*

# %%
con.execute("SELECT COUNT(*) AS RESULT FROM subset_df WHERE Rating > 7 and Runtime < 30 ;")
result = con.fetchdf()
result
# Out:
#    RESULT
# 0  128693

# %% [markdown]
# ## *Q3: How many terrible movies( have rating less than 5)?*

# %%
con.execute("SELECT COUNT(*) AS RESULT FROM subset_df WHERE Rating < 5 ;")
result = con.fetchdf()
result
# Out:
#    RESULT
# 0   66579

# %% [markdown]
# ## *Q4: Which Romance movie has the highest rating?*

# %%
con.execute("SELECT * FROM subset_df WHERE rating = (SELECT MAX(rating) FROM subset_df WHERE Genres LIKE '%Romance%');"  )
result = con.fetchdf()
result
# Out:
#         tconst      Type                       Title  isAdult startYear  \
# 0    tt0127236     video                 Renegades 2        1      1995
# 1    tt0258117     short          Sally in Our Alley        0      1916
# 2    tt0270927   tvMovie         Das Ende vom Anfang        0      1963
# 3    tt0281732     short         Closed for Business        0      1997
# 4    tt0295190   tvMovie  Autobiografija utopljenice        0      1964
# ..         ...       ...                         ...      ...       ...
# 774  tt9226836     short                 Summer Rain        0      2017
# 775  tt9556070     short                    Triple A        0      2022
# 776  tt9614362  tvSeries               Austintatious        0      2017
# 777  tt9646734     short              Dying Out Loud        0      2019
# 778  tt9859322     short                  Temptation        0      2019
#
#     endYear  Runtime                Genres  Rating  NumberofVotes  \
# 0        \N       91                 Adult    10.0             23
# 1        \N       40         Romance,Short    10.0             12
# 2        \N       43                Comedy    10.0             11
# 3        \N        4                 Short    10.0             11
# 4        \N       90                 Drama    10.0             12
# ..      ...      ...                   ...     ...            ...
# 774      \N       20           Drama,Short    10.0              5
# 775      \N       15  Comedy,Drama,Romance    10.0              5
# 776      \N       22          Comedy,Drama    10.0              5
# 777      \N       20     Documentary,Short    10.0             77
# 778      \N       13                 Short    10.0             12
#
#             Director Name
# 0              Buck Adams
# 1        Laurence Trimble
# 2                Erik Ode
# 3          James H. Brown
# 4            Ivan Hetrich
# ..                    ...
# 774  Miwako Van Weyenberg
# 775       J.B. Rutagarama
# 776         Austin Greene
# 777         Jake J. Smith
# 778     Gianni McLaughlin
#
# [779 rows x 11 columns]

# %% [markdown]
# ## *Q5: 20 Romance movies has the highest rating and Number of Votes more than 50*

# %%
con.execute("SELECT * FROM subset_df WHERE Genres LIKE '%Romance%' AND NumberofVotes > 50  ORDER BY Rating DESC LIMIT 20;")
result = con.fetchdf()
result
# Out:
#         tconst       Type                                              Title  \
# 0    tt4678496      short                            Thanks for Accepting Me
# 1   tt15513206      movie                                        Nee Jathaga
# 2   tt16282202  tvEpisode                                       Episode #1.1
# 3   tt16282212  tvEpisode                                       Episode #1.3
# 4    tt9044564  tvEpisode                                       Episode #1.2
# 5   tt14196560  tvEpisode                                       Episode #1.4
# 6    tt1968955  tvEpisode                     I Can't Get Over My First Love
# 7    tt7717890  tvEpisode                                       Wrong Number
# 8    tt8422000      short                                    Half Girlfriend
# 9    tt0583452  tvEpisode                  The One Where Everybody Finds Out
# 10   tt0757574  tvEpisode  With Tired Eyes, Tired Minds, Tired Souls, We ...
# 11   tt1643647  tvEpisode                          Death and All His Friends
# 12   tt1643648  tvEpisode                                          Sanctuary
# 13  tt18815714      movie                                      Prem Prakaran
# 14   tt5251976  tvEpisode                                        How It Ends
# 15   tt8785206  tvEpisode                                       Episode #1.1
# 16  tt19064730  tvEpisode                                          The Train
# 17  tt13580820  tvEpisode                          Somebody Stole My Camera!
# 18  tt13580824  tvEpisode                       Love Is Supposed to Be Crazy
# 19  tt13580828  tvEpisode                      What if You Run Into Your Ex?
#
#     isAdult startYear endYear  Runtime                Genres  Rating  \
# 0         0      2015      \N       25         Romance,Short    10.0
# 1         0      2021      \N      113  Comedy,Drama,Romance    10.0
# 2         0      2022      \N       44  Comedy,Drama,Romance    10.0
# 3         0      2022      \N       39  Comedy,Drama,Romance     9.9
# 4         0      2018      \N       24         Drama,Romance     9.9
# 5         0      2021      \N       50         Drama,Romance     9.8
# 6         0      2011      \N       60   Documentary,Romance     9.8
# 7         0      2017      \N       13        Comedy,Romance     9.8
# 8         0      2014      \N       10         Romance,Short     9.8
# 9         0      1999      \N       22        Comedy,Romance     9.7
# 10        0      2006      \N       44   Drama,Romance,Sport     9.7
# 11        0      2010      \N       60         Drama,Romance     9.7
# 12        0      2010      \N       60         Drama,Romance     9.7
# 13        0        \N      \N      162         Drama,Romance     9.7
# 14        0      2015      \N       21  Drama,Family,Romance     9.7
# 15        0      2018      \N       37         Drama,Romance     9.7
# 16        0      2022      \N       45  Comedy,Drama,Romance     9.7
# 17        0      2021      \N       30         Drama,Romance     9.6
# 18        0      2021      \N       30         Drama,Romance     9.6
# 19        0      2021      \N       30         Drama,Romance     9.6
#
#     NumberofVotes           Director Name
# 0             162           Nikos Kourous
# 1             741        Bamidipati Veera
# 2              55       Hadrah Daeng Ratu
# 3              63       Hadrah Daeng Ratu
# 4              63          Muzammil Desai
# 5              55              Monty Tiwa
# 6              55             Jordan Ross
# 7              68  Aijaz Alladitta Shaikh
# 8              91         V. Jayashankarr
# 9           12282         Michael Lembeck
# 10           1664          Gregory Prange
# 11           3769                Rob Corn
# 12           3370           Stephen Cragg
# 13             69         Chandresh Bhatt
# 14             80        Frank van Keeken
# 15             72          Muzammil Desai
# 16           3052                Ken Olin
# 17             95           Park Shin Woo
# 18             96           Park Shin Woo
# 19             94           Park Shin Woo

# %% [markdown]
# ## *Q6: Top 10 movies has the highest votes and their respective ratings?*

# %%
con.execute("SELECT * FROM subset_df ORDER BY NumberofVotes DESC LIMIT 10;")
result = con.fetchdf()
result
# Out:
#       tconst   Type                                              Title  \
# 0  tt0111161  movie                           The Shawshank Redemption
# 1  tt0468569  movie                                    The Dark Knight
# 2  tt1375666  movie                                          Inception
# 3  tt0137523  movie                                         Fight Club
# 4  tt0109830  movie                                       Forrest Gump
# 5  tt0110912  movie                                       Pulp Fiction
# 6  tt0816692  movie                                       Interstellar
# 7  tt0120737  movie  The Lord of the Rings: The Fellowship of the Ring
# 8  tt0068646  movie                                      The Godfather
# 9  tt0167260  movie      The Lord of the Rings: The Return of the King
#
#    isAdult startYear endYear  Runtime                   Genres  Rating  \
# 0        0      1994      \N      142                    Drama     9.3
# 1        0      2008      \N      152       Action,Crime,Drama     9.0
# 2        0      2010      \N      148  Action,Adventure,Sci-Fi     8.8
# 3        0      1999      \N      139                    Drama     8.8
# 4        0      1994      \N      142            Drama,Romance     8.8
# 5        0      1994      \N      154              Crime,Drama     8.9
# 6        0      2014      \N      169   Adventure,Drama,Sci-Fi     8.7
# 7        0      2001      \N      178   Action,Adventure,Drama     8.8
# 8        0      1972      \N      175              Crime,Drama     9.2
# 9        0      2003      \N      201   Action,Adventure,Drama     9.0
#
#    NumberofVotes         Director Name
# 0        2757004        Frank Darabont
# 1        2729988     Christopher Nolan
# 2        2422670     Christopher Nolan
# 3        2195170         David Fincher
# 4        2144463       Robert Zemeckis
# 5        2117022     Quentin Tarantino
# 6        1923978     Christopher Nolan
# 7        1921752         Peter Jackson
# 8        1918388  Francis Ford Coppola
# 9        1893267         Peter Jackson

# %% [markdown]
# ## *Q7: Duration for short Movies in average?*

# %%
con.execute("SELECT AVG(Runtime) AS average_value FROM subset_df WHERE Type = 'short';")
result = con.fetchdf()
result
# Out:
#    average_value
# 0      14.314315

# %% [markdown]
# **Short Movies often goes around 14.3 minutes**

# %% [markdown]
# ## *Q8: Genres go with Adult movies?*

# %%
con.execute("SELECT Genres FROM df WHERE isAdult = 1 AND Genres NOT LIKE '%N%';")
result = con.fetchdf()
value_counts = result['Genres'].value_counts().head(10)
value_counts
# Out:
# Adult                   11368
# Adult,Comedy              942
# Adult,Romance             600
# Adult,Drama               596
# Adult,Drama,Romance       508
# Adult,Crime,Drama         190
# Adult,Comedy,Romance      161
# Adult,Short               142
# Adult,Comedy,Fantasy      126
# Adult,Horror              122
# Name: Genres, dtype: int64

# %% [markdown]
# ## *Q9: Average Rating of Adult movies?*

# %%
con.execute("SELECT AVG(Rating) AS Average_value FROM subset_df WHERE isAdult = 1 ;")
result = con.fetchdf()
result
# Out:
#    Average_value
# 0       6.196387

# %% [markdown]
# ## *Q10: Top 10 Directors has highest rating for their comedy movies?*

# %%
con.execute("SELECT DirectorName  FROM subset_df WHERE Genres LIKE '%Comedy%' ORDER BY Rating DESC LIMIT 10;")
result = con.fetchdf()
result
# Out:
#         DirectorName
# 0           Erik Ode
# 1     Kerry Brierley
# 2         Jesse Grce
# 3        Hans Scholz
# 4     Jorge Queiroga
# 5        Ronald Baez
# 6              Vidal
# 7      Scott O'Brien
# 8  Hillary Bradfield
# 9       Murray Debus

# %% [markdown]
# ## *Q11: Who often made comedy movies?*

# %%
con.execute("SELECT DirectorName, COUNT(*) as comedy_movie_count FROM subset_df WHERE Genres LIKE '%Comedy%' GROUP BY DirectorName HAVING COUNT(*) > 1 ORDER BY comedy_movie_count DESC LIMIT 10;")
result = con.fetchdf()
result
# Out:
#     DirectorName  comedy_movie_count
# 0   Chuck O'Neil                2199
# 1  James Burrows                 889
# 2    Doug Walker                 824
# 3     Brad Jones                 554
# 4     Joel Zwick                 504
# 5   Gerren Keith                 461
# 6   Dave Diomedi                 459
# 7  James Widdoes                 457
# 8    Alan Rafkin                 454
# 9  Pamela Fryman                 440

# %% [markdown]
# ## *Q12: TV series have high ratings and high number of votes?*

# %%
con.execute("SELECT * FROM subset_df WHERE Type LIKE '%tvSeries%' AND Rating >= (SELECT AVG(Rating) FROM subset_df) AND NumberofVotes >= (SELECT AVG(NumberofVotes) FROM subset_df) ORDER BY Rating DESC;")
result = con.fetchdf()
result
# Out:
#          tconst      Type                                  Title  isAdult  \
# 0     tt2298792  tvSeries                    Alpha Bravo Charlie        0
# 1    tt27548825  tvSeries             Fireflies: Parth Aur Jugnu        0
# 2     tt8284230  tvSeries  The Last Drive-In with Joe Bob Briggs        0
# 3     tt2910420  tvSeries                          Drzavni Posao        0
# 4    tt15251018  tvSeries                              Sabka Sai        0
# ..          ...       ...                                    ...      ...
# 773   tt7939800  tvSeries                     The Undeclared War        0
# 774  tt14935960  tvSeries                       Takt Op. Destiny        0
# 775  tt16968320  tvSeries     RuPaul's Drag Race UK vs the World        0
# 776  tt17074560  tvSeries                              The Rebel        0
# 777   tt7572868  tvSeries                   The Name of the Rose        0
#
#     startYear endYear  Runtime                      Genres  Rating  \
# 0        1998    1998       40                      Action     9.5
# 1        2023      \N       45               Drama,Fantasy     9.5
# 2        2018      \N      125       Comedy,Fantasy,Horror     9.5
# 3        2012      \N       10                      Comedy     9.4
# 4        2021    2021       42             Biography,Drama     9.4
# ..        ...     ...      ...                         ...     ...
# 773      2022    2022       47              Drama,Thriller     6.9
# 774      2021    2021       24  Action,Adventure,Animation     6.9
# 775      2022      \N       70        Game-Show,Reality-TV     6.9
# 776      2022    2022       50                       Drama     6.9
# 777      2019    2019       60       Drama,History,Mystery     6.9
#
#      NumberofVotes      DirectorName
# 0             1810    Shoaib Mansoor
# 1             5225       Hemant Gaba
# 2             1672   Austin Jennings
# 3             3531   Stojce Stoleski
# 4             3375   Ajit Bhairavkar
# ..             ...               ...
# 773           4226   Peter Kosminsky
# 774           1865          Yûki Itô
# 775           1544  Tony Grech-Smith
# 776           3039     Mohammad Kart
# 777           4271  Giacomo Battiato
#
# [778 rows x 11 columns]

# %% [markdown]
# ## *Q13: Which TV series have high ratings and high number of votes released before 2000?*

# %%
con.execute("SELECT * FROM subset_df WHERE Type LIKE '%tvSeries%' AND Rating >= (SELECT AVG(Rating) FROM subset_df) AND NumberofVotes >= (SELECT AVG(NumberofVotes) FROM subset_df) ORDER BY Rating DESC;")
result = con.fetchdf()
# Convert the 'startYear' column to integer
result['startYear'] = result['startYear'].astype(int)
output = result[result['startYear'] < 2000]
output
# Out:
#         tconst      Type                                              Title  \
# 0    tt2298792  tvSeries                                Alpha Bravo Charlie
# 6    tt0077051  tvSeries                                            Matador
# 9    tt0389593  tvSeries                                           Chanakya
# 10   tt0157217  tvSeries                                    Byomkesh Bakshi
# 26   tt0191747  tvSeries                                         Vruc vetar
# ..         ...       ...                                                ...
# 733  tt0064033  tvSeries                           The Ant and the Aardvark
# 734  tt0096681  tvSeries  Prince Caspian and the Voyage of the Dawn Treader
# 753  tt0070996  tvSeries                                   Hong Kong Phooey
# 754  tt0081938  tvSeries                                         Spider-Man
# 755  tt0112064  tvSeries                                           The Mask
#
#      isAdult  startYear endYear  Runtime                      Genres  Rating  \
# 0          0       1998    1998       40                      Action     9.5
# 6          0       1978    1982       67                       Drama     9.3
# 9          0       1990      \N       45               Drama,History     9.3
# 10         0       1993    1997       40     Adventure,Crime,Mystery     9.2
# 26         0       1980    1980       55                      Comedy     9.0
# ..       ...        ...     ...      ...                         ...     ...
# 733        0       1969    1972        6     Animation,Comedy,Family     7.0
# 734        0       1989    1989       30    Adventure,Family,Fantasy     7.0
# 753        0       1974    1975       22  Action,Adventure,Animation     6.9
# 754        0       1981    1982       30  Action,Adventure,Animation     6.9
# 755        0       1995    1997       30  Action,Adventure,Animation     6.9
#
#      NumberofVotes             DirectorName
# 0             1810           Shoaib Mansoor
# 6             5056             Erik Balling
# 9             2652  Chandra Prakash Dwivedi
# 10            3055          Basu Chatterjee
# 26            2581    Aleksandar Djordjevic
# ..             ...                      ...
# 733           1725             Friz Freleng
# 734           2377               Alex Kirby
# 753           3810          Charles Nichols
# 754           1716              Don Jurwich
# 755          12931              Juli Murphy
#
# [84 rows x 11 columns]

# %% [markdown]
# ## *Q14: Which movies have the longest duration and high rating?*

# %%
con.execute("SELECT Type,Title,Genres,Rating,Runtime FROM subset_df WHERE Rating > 7 ORDER BY Runtime DESC LIMIT 10;")
result = con.fetchdf()
result
# Out:
#        Type                                      Title  \
# 0     movie                                        100
# 1     video  The Longest Video on YouTube: 596.5 Hours
# 2     movie                                         Qw
# 3     movie                               Beijing 2003
# 4     movie                                   Ekalavya
# 5     movie                              Nieuwe Tieten
# 6  tvSeries                           White Deer Plain
# 7  tvSeries                             Mundo CurioZoo
# 8  tvSeries                            Kôya no surônin
# 9     movie                            Five-Year Diary
#
#                    Genres  Rating  Runtime
# 0                   Drama     8.4    59460
# 1                      \N     8.0    35791
# 2                   Drama     7.3    10062
# 3             Documentary     7.8     9000
# 4          Drama,Thriller     9.5     5538
# 5       Documentary,Drama     7.8     4080
# 6           Drama,History     8.4     3825
# 7                  Family     7.6     3000
# 8  Action,Adventure,Drama     7.8     2925
# 9             Documentary     8.3     2160

# %% [markdown]
# ## *Q14: Which excellent animation movies have adult content?*

# %%
con.execute("SELECT * FROM subset_df WHERE Genres LIKE '%Animation%' AND isAdult = 1 AND Rating > 8 ORDER BY Rating DESC;")
result = con.fetchdf()
result
# Out:
#         tconst          Type  \
# 0   tt14469506         video
# 1   tt19798926         video
# 2   tt27033264         video
# 3   tt14442664     tvEpisode
# 4   tt24043356  tvMiniSeries
# 5   tt14774320         video
# 6    tt4301484         video
# 7    tt9341024      tvSeries
# 8   tt14544994     tvEpisode
# 9   tt15003770         video
# 10  tt22436676         video
# 11  tt14160224         video
# 12  tt14403508      tvSeries
# 13  tt15299966         video
# 14   tt8832874         video
# 15   tt6672946         video
# 16  tt11663330         video
# 17   tt0283360         short
# 18  tt13012370         video
# 19  tt13821744  tvMiniSeries
# 20  tt14442630     tvEpisode
# 21   tt7427920     tvEpisode
#
#                                                 Title  isAdult startYear  \
# 0                             Dokidoki Little Ooyasan        1      2018
# 1   Anehame: Ore no Hatsukoi ga Jisshi na Wake ga Nai        1      2021
# 2                     FandelTales - The Cursed Prince        1      2022
# 3                             Meru the Succubus OVA 2        1      2020
# 4                                         Harem Camp!        1      2022
# 5                                        Kansen Sodom        1      2018
# 6                                        Lover-in-Law        1      2008
# 7                                     Itadaki! Seieki        1      2014
# 8                             Meru the Succubus OVA 3        1      2021
# 9                                      Knight of Erin        1      2020
# 10                        Kaede to Suzu the Animation        1      2022
# 11                        Kimi ga Suki. The Animation        1      2021
# 12                                  Meru the Succubus        1      2020
# 13  Imaizumin-chi wa Douyara Gal no Tamariba ni Na...        1      2021
# 14  Fella Pure: Mitarashi-san Chi no Jijou The Ani...        1      2014
# 15                          Nightmare: Code Valentine        1      2017
# 16  Spunky Little Brother and His Spunk-Filled Dreams        1      2019
# 17                                           Graphyty        1      1968
# 18                                 Mankitsu Happening        1      2015
# 19                        Master Piece: the Animation        1      2019
# 20                            Meru the Succubus OVA 1        1      2020
# 21                          Nyotai e no First Contact        1      2017
#
#    endYear  Runtime                     Genres  Rating  NumberofVotes  \
# 0       \N      120            Adult,Animation     9.7              6
# 1       \N       40      Adult,Animation,Short     9.6              7
# 2       \N       17    Adult,Animation,Fantasy     9.3             12
# 3       \N       12     Adult,Animation,Comedy     9.3             44
# 4     2022        7    Adult,Animation,Romance     9.0              6
# 5       \N       20     Action,Adult,Animation     9.0              6
# 6       \N       30    Adult,Animation,Romance     8.9             10
# 7     2014       23     Adult,Animation,Comedy     8.9             73
# 8       \N        5     Adult,Animation,Comedy     8.9             33
# 9       \N       80  Adult,Adventure,Animation     8.8              9
# 10      \N       60            Adult,Animation     8.8             21
# 11      \N       60    Adult,Animation,Romance     8.7             11
# 12      \N       10     Adult,Animation,Comedy     8.7            173
# 13      \N       40    Adult,Animation,Romance     8.7             30
# 14      \N       29     Adult,Animation,Comedy     8.6              9
# 15      \N       32     Adult,Animation,Sci-Fi     8.5             12
# 16      \N       26      Adult,Animation,Short     8.4              5
# 17      \N       20      Adult,Animation,Short     8.4             18
# 18      \N      120     Adult,Animation,Comedy     8.1              8
# 19    2019       30            Adult,Animation     8.1             14
# 20      \N        9     Adult,Animation,Comedy     8.1            107
# 21      \N       14    Adult,Animation,Fantasy     8.1             13
#
#            DirectorName
# 0        Ryuuzou Matano
# 1      Toshihiro Watase
# 2              Derpixon
# 3             Jack Pope
# 4      Toshihiro Watase
# 5          Kazuya Komai
# 6          Tsukasa Kado
# 7             Aoi Yuuno
# 8             Jack Pope
# 9           Ayano Kunio
# 10          Hideta Oota
# 11            Pyou Ryuu
# 12            Jack Pope
# 13            Ken Raika
# 14              Tatsumi
# 15             Darkcrow
# 16           Yuji Shiba
# 17  Jean-Pierre Bouyxou
# 18       Ryuuzou Matano
# 19            Ken Raika
# 20            Jack Pope
# 21     Natsumi Kinomoto

# %% [markdown]
# ## *Q15: How many movies of James Cameron  in IMDb dataset?*

# %%
con.execute("SELECT * FROM df WHERE DirectorName LIKE '%James Cameron%';")
result = con.fetchdf()
result
# Out:
#         tconst       Type                                              Title  \
# 0    tt0088247      movie                                     The Terminator
# 1    tt0090605      movie                                             Aliens
# 2    tt0096754      movie                                          The Abyss
# 3    tt0103064      movie                         Terminator 2: Judgment Day
# 4    tt0111503      movie                                          True Lies
# 5    tt0120338      movie                                            Titanic
# 6    tt0297144      movie                                Ghosts of the Abyss
# 7    tt0499549      movie                                             Avatar
# 8    tt0554573  tvEpisode                                       Freak Nation
# 9   tt15738638      video        Terminator 2: Judgment Day - Deleted Scenes
# 10  tt15739442      video        The Terminator: 'Terminated' Deleted Scenes
# 11  tt15739482      video                            Titanic: Deleted Scenes
# 12   tt1630029      movie                           Avatar: The Way of Water
# 13  tt25815526      video  Terminator 2: Judgment Day - Extended Special ...
#
#     isAdult startYear endYear Runtime                    Genres  Rating  \
# 0         0      1984      \N     107             Action,Sci-Fi     8.1
# 1         0      1986      \N     137   Action,Adventure,Sci-Fi     8.4
# 2         0      1989      \N     140   Adventure,Drama,Mystery     7.5
# 3         0      1991      \N     137             Action,Sci-Fi     8.6
# 4         0      1994      \N     141    Action,Comedy,Thriller     7.3
# 5         0      1997      \N     194             Drama,Romance     7.9
# 6         0      2003      \N      61        Documentary,Family     6.8
# 7         0      2009      \N     162  Action,Adventure,Fantasy     7.9
# 8         0      2002      \N      64      Action,Drama,Mystery     8.5
# 9         0      1993      \N      15       Action,Sci-Fi,Short     8.5
# 10        0      2001      \N      10       Action,Sci-Fi,Short     8.3
# 11        0      2012      \N      57       Drama,Romance,Short     8.5
# 12        0      2022      \N     192  Action,Adventure,Fantasy     7.6
# 13        0      1993      \N       2       Action,Sci-Fi,Short     9.1
#
#     NumberofVotes   DirectorName
# 0          888768  James Cameron
# 1          734619  James Cameron
# 2          184091  James Cameron
# 3         1127182  James Cameron
# 4          270477  James Cameron
# 5         1223794  James Cameron
# 6            5895  James Cameron
# 7         1348513  James Cameron
# 8             501  James Cameron
# 9             307  James Cameron
# 10            226  James Cameron
# 11            669  James Cameron
# 12         417733  James Cameron
# 13             34  James Cameron
