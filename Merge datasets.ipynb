# %% [markdown]
# # Merging different IMDb dataframes into one dataset
#
# ### *Author: Hank Hoang*
# ### *Date created: 28/06/2023*
# ### *Date finished: 29/06/2023*

# %% [markdown]
# ## Note
# * Due to limited facilities(insufficient RAM), the principal.tsv dataset is too large (2.51GB) for my laptop, my Jupiter notebook couldn't load it, even Google colab can't bear this case, and the dataset made it collapse. So I skipped this dataset for this time.
# * Merge Crew and Name_basic datasets into one dataset to retrieve director names.
# * Using inner join to merge datasets.
# * \N’ is used to denote that a particular field is missing or null for that title/name.

# %%
# Import libraries
import pandas as pd

# %%
data1=pd.read_csv('title_basic.tsv',sep='\t')
data2=pd.read_csv('rating.tsv',sep='\t')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9268\3480055702.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv('title_basic.tsv',sep='\t')

# %%
data1.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %% [markdown]
# Basically, originalTitle is pretty much the same as primaryTitle but primaryTitle is more well-known for commercial purposes.Therefore, delete originalTitle column

# %%
# Delete 'originalTitle' column
data1.drop('originalTitle', inplace=True, axis=1)

# %%
data1.head()
# Out:
#       tconst titleType            primaryTitle isAdult startYear endYear  \
# 0  tt0000001     short              Carmencita       0      1894      \N
# 1  tt0000002     short  Le clown et ses chiens       0      1892      \N
# 2  tt0000003     short          Pauvre Pierrot       0      1892      \N
# 3  tt0000004     short             Un bon bock       0      1892      \N
# 4  tt0000005     short        Blacksmith Scene       0      1893      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short

# %%
data2.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1982
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1838
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2625

# %%
df_inner = pd.merge(data1, data2, on='tconst', how='inner')
df_inner
# Out:
#             tconst  titleType                primaryTitle isAdult startYear  \
# 0        tt0000001      short                  Carmencita       0      1894
# 1        tt0000002      short      Le clown et ses chiens       0      1892
# 2        tt0000003      short              Pauvre Pierrot       0      1892
# 3        tt0000004      short                 Un bon bock       0      1892
# 4        tt0000005      short            Blacksmith Scene       0      1893
# ...            ...        ...                         ...     ...       ...
# 1324193  tt9916730      movie                      6 Gunn       0      2017
# 1324194  tt9916766  tvEpisode              Episode #10.15       0      2019
# 1324195  tt9916778  tvEpisode                      Escape       0      2019
# 1324196  tt9916840  tvEpisode  Horrid Henry's Comic Caper       0      2014
# 1324197  tt9916880  tvEpisode   Horrid Henry Knows It All       0      2014
#
#         endYear runtimeMinutes                       genres  averageRating  \
# 0            \N              1            Documentary,Short            5.7
# 1            \N              5              Animation,Short            5.8
# 2            \N              4     Animation,Comedy,Romance            6.5
# 3            \N             12              Animation,Short            5.5
# 4            \N              1                 Comedy,Short            6.2
# ...         ...            ...                          ...            ...
# 1324193      \N            116                           \N            8.3
# 1324194      \N             43  Family,Game-Show,Reality-TV            7.0
# 1324195      \N             \N          Crime,Drama,Mystery            7.2
# 1324196      \N             11   Adventure,Animation,Comedy            7.5
# 1324197      \N             10   Adventure,Animation,Comedy            7.0
#
#          numVotes
# 0            1982
# 1             265
# 2            1838
# 3             178
# 4            2625
# ...           ...
# 1324193        10
# 1324194        21
# 1324195        36
# 1324196         7
# 1324197         7
#
# [1324198 rows x 10 columns]

# %%
data2
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1982
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1838
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2625
# ...            ...            ...       ...
# 1324193  tt9916730            8.3        10
# 1324194  tt9916766            7.0        21
# 1324195  tt9916778            7.2        36
# 1324196  tt9916840            7.5         7
# 1324197  tt9916880            7.0         7
#
# [1324198 rows x 3 columns]

# %%
data3=pd.read_csv('name_basic.tsv',sep='\t')

# %%
data3.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0050419,tt0072308,tt0053137
# 1  tt0037382,tt0038355,tt0075213,tt0117057
# 2  tt0056404,tt0049189,tt0057345,tt0054452
# 3  tt0077975,tt0072562,tt0078723,tt0080455
# 4  tt0050976,tt0083922,tt0050986,tt0069467

# %%
#Delete unnecessary columns
data3.drop(['birthYear','deathYear','primaryProfession','knownForTitles'], inplace=True, axis=1)

# %%
data3.head()
# Out:
#       nconst      primaryName
# 0  nm0000001     Fred Astaire
# 1  nm0000002    Lauren Bacall
# 2  nm0000003  Brigitte Bardot
# 3  nm0000004     John Belushi
# 4  nm0000005   Ingmar Bergman

# %%
data4=pd.read_csv('crew.tsv',sep='\t')

# %%
data4.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
# Delete 'writers' column
data4.drop('writers', inplace=True, axis=1)

# %%
#Change name for director column into nconst
data4.rename(columns={'directors': 'nconst'}, inplace=True)

# %%
data4
# Out:
#             tconst               nconst
# 0        tt0000001            nm0005690
# 1        tt0000002            nm0721526
# 2        tt0000003            nm0721526
# 3        tt0000004            nm0721526
# 4        tt0000005            nm0005690
# ...            ...                  ...
# 9963675  tt9916848            nm1485677
# 9963676  tt9916850            nm1485677
# 9963677  tt9916852            nm1485677
# 9963678  tt9916856           nm10538645
# 9963679  tt9916880  nm0584014,nm0996406
#
# [9963680 rows x 2 columns]

# %% [markdown]
# ### Merge crew and name_basic datasets into one

# %%
df_inner2 = pd.merge(data3, data4, on='nconst', how='inner')
df_inner2
# Out:
#             nconst       primaryName      tconst
# 0        nm0000005    Ingmar Bergman   tt0038468
# 1        nm0000005    Ingmar Bergman   tt0038675
# 2        nm0000005    Ingmar Bergman   tt0039834
# 3        nm0000005    Ingmar Bergman   tt0040418
# 4        nm0000005    Ingmar Bergman   tt0040622
# ...            ...               ...         ...
# 4617723  nm9993694    Chinmay Mishra  tt18361688
# 4617724  nm9993694    Chinmay Mishra  tt18687502
# 4617725  nm9993696  Ibrahim-Aloduley   tt8744160
# 4617726  nm9993708        Eli Bevins   tt9046122
# 4617727  nm9993709         Lu Bevins  tt11697102
#
# [4617728 rows x 3 columns]

# %%
# Change column name to denote directors' name
df_inner2.rename(columns={'primaryName': 'Director Name'}, inplace=True)

# %%
df_inner2.head()
# Out:
#       nconst   Director Name     tconst
# 0  nm0000005  Ingmar Bergman  tt0038468
# 1  nm0000005  Ingmar Bergman  tt0038675
# 2  nm0000005  Ingmar Bergman  tt0039834
# 3  nm0000005  Ingmar Bergman  tt0040418
# 4  nm0000005  Ingmar Bergman  tt0040622

# %%
# Delete 'nconst' column
df_inner2.drop('nconst', inplace=True, axis=1)

# %%
df_inner2
# Out:
#             Director Name      tconst
# 0          Ingmar Bergman   tt0038468
# 1          Ingmar Bergman   tt0038675
# 2          Ingmar Bergman   tt0039834
# 3          Ingmar Bergman   tt0040418
# 4          Ingmar Bergman   tt0040622
# ...                   ...         ...
# 4617723    Chinmay Mishra  tt18361688
# 4617724    Chinmay Mishra  tt18687502
# 4617725  Ibrahim-Aloduley   tt8744160
# 4617726        Eli Bevins   tt9046122
# 4617727         Lu Bevins  tt11697102
#
# [4617728 rows x 2 columns]

# %% [markdown]
# ## Merge all transformed datasets into the final dataset

# %%
df = pd.merge(df_inner, df_inner2, on='tconst', how='inner')
df.head()
# Out:
#       tconst titleType            primaryTitle isAdult startYear endYear  \
# 0  tt0000001     short              Carmencita       0      1894      \N
# 1  tt0000002     short  Le clown et ses chiens       0      1892      \N
# 2  tt0000003     short          Pauvre Pierrot       0      1892      \N
# 3  tt0000004     short             Un bon bock       0      1892      \N
# 4  tt0000005     short        Blacksmith Scene       0      1893      \N
#
#   runtimeMinutes                    genres  averageRating  numVotes  \
# 0              1         Documentary,Short            5.7      1982
# 1              5           Animation,Short            5.8       265
# 2              4  Animation,Comedy,Romance            6.5      1838
# 3             12           Animation,Short            5.5       178
# 4              1              Comedy,Short            6.2      2625
#
#           Director Name
# 0  William K.L. Dickson
# 1         Émile Reynaud
# 2         Émile Reynaud
# 3         Émile Reynaud
# 4  William K.L. Dickson

# %%
# Change column names 
df.rename(columns={'genres': 'Genres','primaryTitle':'Title','titleType':'Type','runtimeMinutes':'Runtime','averageRating':'Rating','numVotes':'Number of Votes'}, inplace=True)

# %%
df.head()
# Out:
#       tconst   Type                   Title isAdult startYear endYear Runtime  \
# 0  tt0000001  short              Carmencita       0      1894      \N       1
# 1  tt0000002  short  Le clown et ses chiens       0      1892      \N       5
# 2  tt0000003  short          Pauvre Pierrot       0      1892      \N       4
# 3  tt0000004  short             Un bon bock       0      1892      \N      12
# 4  tt0000005  short        Blacksmith Scene       0      1893      \N       1
#
#                      Genres  Rating  Number of Votes         Director Name
# 0         Documentary,Short     5.7             1982  William K.L. Dickson
# 1           Animation,Short     5.8              265         Émile Reynaud
# 2  Animation,Comedy,Romance     6.5             1838         Émile Reynaud
# 3           Animation,Short     5.5              178         Émile Reynaud
# 4              Comedy,Short     6.2             2625  William K.L. Dickson

# %%
#Saving dataset
df.to_csv('IMDb_data.csv', index=False)
